# %%
# 1. Importació de llibreries
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from tqdm import tqdm

# %%
# 2. Carreguem dades
df = pd.read_csv("datosFinal.csv")
df
# Out:
#       Startup                Company  \
# 0      EQUITO         EQUITO APP S.L
# 1        VORA                   VORA
# 2     LEXDOKA  SEEDFY ECOSYSTEM S.L.
# 3      KOKUAI            KOKUAI S.L.
# 4     FLAMAID           FLAMAID S.L.
# ..        ...                    ...
# 63    TALKUAL    IMPERFECTUS BOX S.L
# 64   COCOPOOL        PLACE4PLAN S.L.
# 65  GET-PIZZA        APPASSIONE S.L.
# 66     LAAGAM           CID BRAND SL
# 67  RIMBARLAT         RIMBARLAT S.L.
#
#                                          Category Investment  \
# 0                               FinancingProptech     0.3M €
# 1                                Fashion & Design     0.3M €
# 2           Business Services & SoftwareLegaltech     0.3M €
# 3          HealthtechBusiness Services & Software     0.3M €
# 4                                        Hardware     0.3M €
# ..                                            ...        ...
# 63                  E-commerce & MarketplacesFood     0.1M €
# 64  E-commerce & MarketplacesTraveltech & Leisure     0.1M €
# 65                              FoodLogistic Tech     0.0M €
# 66                               Fashion & Design        NaN
# 67                               HealthtechSports        NaN
#
#                                 Investors            Date  \
# 0                               Lanzadera       June 2024
# 1          Casilda Güell i Javier Sobrino       June 2024
# 2                         Codols Finances        May 2024
# 3   Elisabeth Martinez, Oriol Vila, Blast  September 2024
# 4                             ONA Capital       July 2024
# ..                                    ...             ...
# 63                        Business Angels       June 2024
# 64                              Fundadors       June 2024
# 65                              Fundadors       June 2024
# 66                            Tomas Meyer    October 2024
# 67                   Barça Innovation Hub    October 2024
#
#                                  URL                   Name  \
# 0      startup/barcelona/equito/5843         EQUITO APP S.L
# 1        startup/barcelona/vora/6706                   VORA
# 2     startup/barcelona/lexdoka/6563  SEEDFY ECOSYSTEM S.L.
# 3      startup/barcelona/kokuai/5838            KOKUAI S.L.
# 4     startup/barcelona/flamaid/7137           FLAMAID S.L.
# ..                               ...                    ...
# 63       startup/lleida/talkual/5126    IMPERFECTUS BOX S.L
# 64   startup/barcelona/cocopool/6433        PLACE4PLAN S.L.
# 65  startup/barcelona/get-pizza/6718        APPASSIONE S.L.
# 66     startup/barcelona/laagam/5599           CID BRAND SL
# 67  startup/barcelona/rimbarlat/5928         RIMBARLAT S.L.
#
#                                           Description  \
# 0   ['A real estate investment platform enabling u...
# 1   ['Vora is inspired by the city of Barcelona, p...
# 2   ['LexDoka is a collaborative platform that tur...
# 3   ['Kokuai is a Barcelona based start-up founded...
# 4   ['Flamaid is a safety device equipped with an ...
# ..                                                ...
# 63  ['Talkual is a delivery service for imperfect ...
# 64  ['Platform for renting private pools by the ho...
# 65  ['Online food ordering platform connecting art...
# 66  ['We inspire girls to take the world by storm....
# 67  ['Regenerative medicine for sports muscle inju...
#
#                                               Address  ...  \
# 0             ['Paseig De Gracia 19 08007 Barcelona']  ...
# 1   ['Calle Cavallers, 54 P. 4 Pta. 1 08034 Barcel...  ...
# 2              ['Calle Pallars, 108 08018 Barcelona']  ...
# 3             ['Carrer Llacuna, 162 08018 Barcelona']  ...
# 4   ['Calle Salvador Espriu, 47 P. 5 Pta. 1 08005 ...  ...
# ..                                                ...  ...
# 63          ['Avinguda Lleida, 32  25250,0 Bellpuig']  ...
# 64  ['Urbanizacion Cabrils Ii (crta Cabrils A Vila...  ...
# 65        ['Carrer De La Rosella 17 08035 Barcelona']  ...
# 66         ['Pasaje Marimon, 23 Loc 08021 Barcelona']  ...
# 67  ['Avinguda De La Riera De Cassoles, 43 4 08012...  ...
#
#                                          Technologies          Other fields  \
# 0   ['Fintech & Insurtech, \r\n\t\t               ...    ['Social Economy']
# 1                                      ['E-commerce']    ['Social Economy']
# 2   ['Fintech & Insurtech, \r\n\t\t               ...      ['Industry 4.0']
# 3   ['AI & Big Data, \r\n\t\t                \t\t\...                 ['-']
# 4                                   ['IoT & Sensors']    ['Social Economy']
# ..                                                ...                   ...
# 63  ['E-commerce, \r\n\t\t                \t\t\r\n...  ['Circular Economy']
# 64  ['AI & Big Data, \r\n\t\t                \t\t\...   ['Sharing Economy']
# 65  ['E-commerce, \r\n\t\t                \t\t\r\n...      ['Smart Cities']
# 66                                     ['E-commerce']                 ['-']
# 67  ['Personalized medicine, \r\n\t\t             ...                 ['-']
#
#                         Funding stage   Founded          Employees  \
# 0   ['Seed (0.25 M EUR - < 1 M EUR)']  ['2021']  ['From 11 to 20']
# 1   ['Seed (0.25 M EUR - < 1 M EUR)']  ['2022']    ['Undisclosed']
# 2   ['Seed (0.25 M EUR - < 1 M EUR)']  ['2021']    ['Undisclosed']
# 3   ['Seed (0.25 M EUR - < 1 M EUR)']  ['2020']    ['From 1 to 5']
# 4   ['Seed (0.25 M EUR - < 1 M EUR)']  ['2023']    ['Undisclosed']
# ..                                ...       ...                ...
# 63        ['Pre-seed (< 0.25 M EUR)']  ['2019']  ['From 21 to 50']
# 64        ['Pre-seed (< 0.25 M EUR)']  ['2022']    ['Undisclosed']
# 65        ['Pre-seed (< 0.25 M EUR)']  ['2023']    ['From 1 to 5']
# 66  ['Seed (0.25 M EUR - < 1 M EUR)']  ['2016']   ['From 6 to 10']
# 67  ['Seed (0.25 M EUR - < 1 M EUR)']  ['2020']    ['Undisclosed']
#
#                                        Business model  \
# 0                                     ['Marketplace']
# 1                                               ['-']
# 2                                            ['Saas']
# 3                                            ['Saas']
# 4                     ['Development & Manufacturing']
# ..                                                ...
# 63  ['Ecommerce & Trade, \nMarketplace, \nSaas, \n...
# 64                                    ['Marketplace']
# 65                              ['Ecommerce & Trade']
# 66                                           ['Saas']
# 67                                         ['Others']
#
#                       Target               Spinoff participants  \
# 0               ['Consumer']           ['None / Not a spinoff']
# 1               ['Consumer']           ['None / Not a spinoff']
# 2               ['Business']           ['None / Not a spinoff']
# 3               ['Business']           ['None / Not a spinoff']
# 4               ['Consumer']           ['None / Not a spinoff']
# ..                       ...                                ...
# 63  ['Business, \nConsumer']          ['Company /Other Centre']
# 64              ['Consumer']           ['None / Not a spinoff']
# 65  ['Business, \nConsumer']           ['None / Not a spinoff']
# 66                     ['-']           ['None / Not a spinoff']
# 67              ['Business']  ['Technological Centre (BIOCAT)']
#
#                                               Funding  \
# 0   [[{'amount': '0.3M € (June 2024)', 'date': 'Ju...
# 1   [[{'amount': '0.3M € (June 2024)', 'date': 'Ju...
# 2   [[{'amount': '0.3M € (May 2024)', 'date': 'May...
# 3   [[{'amount': '0.3M € (September 2024)', 'date'...
# 4   [[{'amount': '0.1M € (November 2024)', 'date':...
# ..                                                ...
# 63  [[{'amount': '0.1M € (June 2024)', 'date': 'Ju...
# 64  [[{'amount': '0.1M € (June 2024)', 'date': 'Ju...
# 65  [[{'amount': '0.0M € (June 2024)', 'date': 'Ju...
# 66  [[{'amount': '(October 2024)', 'date': 'Octobe...
# 67  [[{'amount': '(October 2024)', 'date': 'Octobe...
#
#                                              Funding2
# 0   ['Funding\n0.3M € (JUNE 2024)\nCapital\nInvest...
# 1   ['Funding\n0.3M € (JUNE 2024)\nCapital\nInvest...
# 2   ['Funding\n0.3M € (MAY 2024)\nCapital\nInvesto...
# 3   ['Funding\n0.3M € (SEPTEMBER 2024)\nCapital\nI...
# 4   ['Funding\n0.1M € (NOVEMBER 2024)\nCapital\nIn...
# ..                                                ...
# 63  ['Funding\n0.1M € (JUNE 2024)\nCapital\nInvest...
# 64  ['Funding\n0.1M € (JUNE 2024)\nCapital\nInvest...
# 65  ['Funding\n0.0M € (JUNE 2024)\nCapital\nInvest...
# 66  ['Funding\n(OCTOBER 2024)\nCapital\nInvestors:...
# 67  ['Funding\n(OCTOBER 2024)\ncapital\nInvestors:...
#
# [68 rows x 21 columns]
